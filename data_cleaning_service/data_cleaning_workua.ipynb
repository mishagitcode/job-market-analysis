# %% [markdown]
# # Data Cleaning & Transformation
#
#
#
# **Input:** `data/parsed_data/parsed_data_wokua.csv`
#
# **Output:** `data/cleaned_data/cleaned_data_workua_data.csv`

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os

if not os.path.exists("requirements.txt"):
    os.chdir("..")

from data_cleaning_service.utils.utils_workua import parse_salary, clean_and_normalize_skills

# %% [markdown]
# ## Data upload

# %%
df = pd.read_csv("data/parsed_data/parsed_data_workua.csv")

df.head()
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company       salary location  office  remote  \
# 0      Будыкин С.А., ФЛП            0        0       0       1
# 1  UKEESS Software House            0        0       0       1
# 2       ITishniki school  10000–20000        0       0       1
# 3          Новотест, ООО  40000–80000   Дніпро       1       0
# 4               Halo Lab            0        0       0       1
#
#    years_of_experience                                             skills
# 0                    0                         Відповідальність,Уважність
# 1                    5   SQL,Git,Python,Jenkins,AWS,Terraform,NoSQL,CI/CD
# 2                    1  Відповідальність,Доброзичливість,Python,HTML,C...
# 3                    0                     Відповідальність,Самостійність
# 4                    1  SQL,Git,JavaScript,Python,PostgreSQL,React,Doc...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   specialization       105 non-null    object
#  1   title                105 non-null    object
#  2   company              105 non-null    object
#  3   salary               105 non-null    object
#  4   location             105 non-null    object
#  5   office               105 non-null    int64
#  6   remote               105 non-null    int64
#  7   years_of_experience  105 non-null    int64
#  8   skills               105 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 7.5+ KB

# %%
df.describe()
# Out:
#            office      remote  years_of_experience
# count  105.000000  105.000000           105.000000
# mean     0.485714    0.514286          1026.733333
# std      0.502193    0.502193          7634.096888
# min      0.000000    0.000000             0.000000
# 25%      0.000000    0.000000             0.000000
# 50%      0.000000    1.000000             1.000000
# 75%      1.000000    1.000000             2.000000
# max      1.000000    1.000000         67496.000000

# %% [markdown]
# ## Salary column cleaning and transformation

# %%
salary_metrics = df["salary"].apply(parse_salary)

df["min_salary"] = [x[0] for x in salary_metrics]
df["max_salary"] = [x[1] for x in salary_metrics]
df["avg_salary"] = [x[2] for x in salary_metrics]

print(f"Salaries parsed. Missing salary count: {df['avg_salary'].isna().sum()}")
df.head(10)
# Out:
# Salaries parsed. Missing salary count: 54
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
# 5         python                       Python, AI Chatbot Developer
# 6         python       Спеціаліст з автоматизації процесів (Python)
# 7         python  Викладач курсу Python для дітей (9-16 р., онлайн)
# 8         python                          Програміст С, С++, Python
# 9         python                            Python Developer (Odoo)
#
#                                            company        salary     location  \
# 0                                Будыкин С.А., ФЛП             0            0
# 1                            UKEESS Software House             0            0
# 2                                 ITishniki school   10000–20000            0
# 3                                    Новотест, ООО   40000–80000       Дніпро
# 4                                         Halo Lab             0            0
# 5                                       OnLifeTime  40000–100000            0
# 6                           AMZ, Recruiting Agency             0            0
# 7                            Академія покоління IT   25000–45000            0
# 8  6 центр рекрутингу Сил Безпілотних Систем (СБС)         50000  Вся Україна
# 9                                             ToDo             0            0
#
#    office  remote  years_of_experience  \
# 0       0       1                    0
# 1       0       1                    5
# 2       0       1                    1
# 3       1       0                    0
# 4       0       1                    1
# 5       0       1                    1
# 6       0       1                    0
# 7       0       1                    1
# 8       1       0                    1
# 9       0       1                    1
#
#                                               skills  min_salary  max_salary  \
# 0                         Відповідальність,Уважність         NaN         NaN
# 1   SQL,Git,Python,Jenkins,AWS,Terraform,NoSQL,CI/CD         NaN         NaN
# 2  Відповідальність,Доброзичливість,Python,HTML,C...     10000.0     20000.0
# 3                     Відповідальність,Самостійність     40000.0     80000.0
# 4  SQL,Git,JavaScript,Python,PostgreSQL,React,Doc...         NaN         NaN
# 5  JavaScript,Ведення CRM,Python,Аналітичне мисле...     40000.0    100000.0
# 6  Відповідальність,Організованість,Уважність,AI,...         NaN         NaN
# 7                                   Відповідальність     25000.0     45000.0
# 8                                                  0     50000.0     50000.0
# 9  Користувач ОС Linux,Python,PostgreSQL,JSON,Від...         NaN         NaN
#
#    avg_salary
# 0         NaN
# 1         NaN
# 2     15000.0
# 3     60000.0
# 4         NaN
# 5     70000.0
# 6         NaN
# 7     35000.0
# 8     50000.0
# 9         NaN

# %%
df.drop("salary", axis=1, inplace=True)

df.head(5)
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company location  office  remote  years_of_experience  \
# 0      Будыкин С.А., ФЛП        0       0       1                    0
# 1  UKEESS Software House        0       0       1                    5
# 2       ITishniki school        0       0       1                    1
# 3          Новотест, ООО   Дніпро       1       0                    0
# 4               Halo Lab        0       0       1                    1
#
#                                               skills  min_salary  max_salary  \
# 0                         Відповідальність,Уважність         NaN         NaN
# 1   SQL,Git,Python,Jenkins,AWS,Terraform,NoSQL,CI/CD         NaN         NaN
# 2  Відповідальність,Доброзичливість,Python,HTML,C...     10000.0     20000.0
# 3                     Відповідальність,Самостійність     40000.0     80000.0
# 4  SQL,Git,JavaScript,Python,PostgreSQL,React,Doc...         NaN         NaN
#
#    avg_salary
# 0         NaN
# 1         NaN
# 2     15000.0
# 3     60000.0
# 4         NaN

# %% [markdown]
# ## Skills column cleaning and transformation

# %%
df["skills_normalized"] = df["skills"].apply(clean_and_normalize_skills)

skills_dummies = df["skills_normalized"].str.get_dummies(sep=",")

df_final = pd.concat([df, skills_dummies], axis=1)

df_final.head(5)
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company location  office  remote  years_of_experience  \
# 0      Будыкин С.А., ФЛП        0       0       1                    0
# 1  UKEESS Software House        0       0       1                    5
# 2       ITishniki school        0       0       1                    1
# 3          Новотест, ООО   Дніпро       1       0                    0
# 4               Halo Lab        0       0       1                    1
#
#                                               skills  min_salary  max_salary  \
# 0                         Відповідальність,Уважність         NaN         NaN
# 1   SQL,Git,Python,Jenkins,AWS,Terraform,NoSQL,CI/CD         NaN         NaN
# 2  Відповідальність,Доброзичливість,Python,HTML,C...     10000.0     20000.0
# 3                     Відповідальність,Самостійність     40000.0     80000.0
# 4  SQL,Git,JavaScript,Python,PostgreSQL,React,Doc...         NaN         NaN
#
#    ...  Тестування api Тестування мобільних застосунків  Тестування пз  \
# 0  ...               0                                0              0
# 1  ...               0                                0              0
# 2  ...               0                                0              0
# 3  ...               0                                0              0
# 4  ...               0                                0              0
#
#    Уважність  Уміння аналізувати  Уміння мотивувати  Управління командою  \
# 0          1                   0                  0                    0
# 1          0                   0                  0                    0
# 2          0                   0                  1                    0
# 3          0                   0                  0                    0
# 4          0                   0                  0                    0
#
#    Фінансове планування  Цілеспрямованість  Чесність
# 0                     0                  0         0
# 1                     0                  0         0
# 2                     0                  0         0
# 3                     0                  0         0
# 4                     0                  0         0
#
# [5 rows x 305 columns]

# %%
df_final.drop(["skills", "skills_normalized"], axis=1, inplace=True)

df_final.head(5)
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company location  office  remote  years_of_experience  \
# 0      Будыкин С.А., ФЛП        0       0       1                    0
# 1  UKEESS Software House        0       0       1                    5
# 2       ITishniki school        0       0       1                    1
# 3          Новотест, ООО   Дніпро       1       0                    0
# 4               Halo Lab        0       0       1                    1
#
#    min_salary  max_salary  avg_salary  ...  Тестування api  \
# 0         NaN         NaN         NaN  ...               0
# 1         NaN         NaN         NaN  ...               0
# 2     10000.0     20000.0     15000.0  ...               0
# 3     40000.0     80000.0     60000.0  ...               0
# 4         NaN         NaN         NaN  ...               0
#
#    Тестування мобільних застосунків  Тестування пз  Уважність  \
# 0                                 0              0          1
# 1                                 0              0          0
# 2                                 0              0          0
# 3                                 0              0          0
# 4                                 0              0          0
#
#    Уміння аналізувати  Уміння мотивувати  Управління командою  \
# 0                   0                  0                    0
# 1                   0                  0                    0
# 2                   0                  1                    0
# 3                   0                  0                    0
# 4                   0                  0                    0
#
#    Фінансове планування  Цілеспрямованість  Чесність
# 0                     0                  0         0
# 1                     0                  0         0
# 2                     0                  0         0
# 3                     0                  0         0
# 4                     0                  0         0
#
# [5 rows x 303 columns]

# %% [markdown]
# ## Location column cleaning and transformation

# %%
df_final["location"] = df_final["location"].replace("0", "Unknown")

df_final.head(5)
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company location  office  remote  years_of_experience  \
# 0      Будыкин С.А., ФЛП  Unknown       0       1                    0
# 1  UKEESS Software House  Unknown       0       1                    5
# 2       ITishniki school  Unknown       0       1                    1
# 3          Новотест, ООО   Дніпро       1       0                    0
# 4               Halo Lab  Unknown       0       1                    1
#
#    min_salary  max_salary  avg_salary  ...  Тестування api  \
# 0         NaN         NaN         NaN  ...               0
# 1         NaN         NaN         NaN  ...               0
# 2     10000.0     20000.0     15000.0  ...               0
# 3     40000.0     80000.0     60000.0  ...               0
# 4         NaN         NaN         NaN  ...               0
#
#    Тестування мобільних застосунків  Тестування пз  Уважність  \
# 0                                 0              0          1
# 1                                 0              0          0
# 2                                 0              0          0
# 3                                 0              0          0
# 4                                 0              0          0
#
#    Уміння аналізувати  Уміння мотивувати  Управління командою  \
# 0                   0                  0                    0
# 1                   0                  0                    0
# 2                   0                  1                    0
# 3                   0                  0                    0
# 4                   0                  0                    0
#
#    Фінансове планування  Цілеспрямованість  Чесність
# 0                     0                  0         0
# 1                     0                  0         0
# 2                     0                  0         0
# 3                     0                  0         0
# 4                     0                  0         0
#
# [5 rows x 303 columns]

# %% [markdown]
# ## Years of expirience column cleaning and transformation

# %%
df_final["years_of_experience"].describe()
# Out:
# count      105.000000
# mean      1026.733333
# std       7634.096888
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max      67496.000000
# Name: years_of_experience, dtype: float64

# %%
df_final["years_of_experience"] = df_final["years_of_experience"].apply(
    lambda x: np.nan if x > 30 else x
)

df_final.head(5)
# Out:
#   specialization                                              title  \
# 0         python                                   Python Developer
# 1         python                             Senior Python Engineer
# 2         python  Вчитель з програмування (створення ігор, вебро...
# 3         python  Програміст для розробки інтерфейсів вимірюваль...
# 4         python                         Python developer (FastAPI)
#
#                  company location  office  remote  years_of_experience  \
# 0      Будыкин С.А., ФЛП  Unknown       0       1                  0.0
# 1  UKEESS Software House  Unknown       0       1                  5.0
# 2       ITishniki school  Unknown       0       1                  1.0
# 3          Новотест, ООО   Дніпро       1       0                  0.0
# 4               Halo Lab  Unknown       0       1                  1.0
#
#    min_salary  max_salary  avg_salary  ...  Тестування api  \
# 0         NaN         NaN         NaN  ...               0
# 1         NaN         NaN         NaN  ...               0
# 2     10000.0     20000.0     15000.0  ...               0
# 3     40000.0     80000.0     60000.0  ...               0
# 4         NaN         NaN         NaN  ...               0
#
#    Тестування мобільних застосунків  Тестування пз  Уважність  \
# 0                                 0              0          1
# 1                                 0              0          0
# 2                                 0              0          0
# 3                                 0              0          0
# 4                                 0              0          0
#
#    Уміння аналізувати  Уміння мотивувати  Управління командою  \
# 0                   0                  0                    0
# 1                   0                  0                    0
# 2                   0                  1                    0
# 3                   0                  0                    0
# 4                   0                  0                    0
#
#    Фінансове планування  Цілеспрямованість  Чесність
# 0                     0                  0         0
# 1                     0                  0         0
# 2                     0                  0         0
# 3                     0                  0         0
# 4                     0                  0         0
#
# [5 rows x 303 columns]

# %%
df_final["years_of_experience"].describe()
# Out:
# count    103.000000
# mean       1.077670
# std        1.311258
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: years_of_experience, dtype: float64

# %% [markdown]
# ## Saving the cleaned and transformed data

# %%
df_final.to_csv("data/cleaned_data/cleaned_data_workua.csv", index=False)
